# %%
import requests
import polyline
import json
import pandas as pd
from shapely.geometry import Point
import folium
import geopandas as gpd
import dotenv
import os
import matplotlib.pyplot as plt
from openrouteservice import convert
from geopy.distance import geodesic
import numpy as np
import math
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import requests
# ----> 2 import polyline
#       3 import json
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'polyline'

# %%
dotenv.load_dotenv()
ORS_API_KEY=os.getenv('ORS_API_KEY')
AZURE_API_KEY=os.getenv('AZURE_API_KEY')

# %%
# [Lat,lon] format
def generate_map(coords):
    m=folium.Map(location=coords[0], zoom_start=12)
    folium.Marker(coords[0]).add_to(m)
    folium.Marker(coords[-1]).add_to(m)
    folium.PolyLine(
        coords,
        color="blue",
        weight=5,
        opacity=0.8
    ).add_to(m)
    return m

#line=convert.decode_polyline(ors["routes"][0]["geometry"],False)
#generate_map([[lat,lon]for lon,lat in line["coordinates"]])

# %%
def get_alt(coordinates, api_key):
    url = "https://api.openrouteservice.org/elevation/line"
    headers = {
        "Authorization": api_key,
        "Content-Type": "application/json"
    }

    # ORS espera formato lat, lon para ENCODED_POLYLINE
    geometry_latlng = [(lat, lng) for lng, lat in coordinates]

    payload = {
        "format_in": "encodedpolyline",
        "format_out": "geojson",
        "geometry": polyline.encode(geometry_latlng)
    }

    response = requests.post(url, headers=headers, json=payload)
    if response.status_code != 200:
        raise Exception(f"Error elevación: {response.text}")
    data = response.json()
    return data['geometry']['coordinates']

# %%
# lon, lat format
def get_route(coords,api_key):
    url = "https://api.openrouteservice.org/v2/directions/driving-car"
    headers = {
        "Authorization": api_key,
        "Content-Type": "application/json"
    }
    payload = {
        "coordinates": coords,
        "instructions": True,
        "elevation":True
    }

    response = requests.post(url, json=payload, headers=headers)
    if response.status_code != 200:
        raise Exception(f"Error elevación: {response.text}")
    
    data = response.json()
    return data

# %%
def get_traffic_incidents(bbox, subscription_key):
    base_url = "https://atlas.microsoft.com/traffic/incident"
    params = {
        "api-version": "2025-01-01",
        "incidentType":"Accident",
        "bbox": ",".join(map(str, bbox))
    }
    headers = {}
    headers["subscription-key"] = subscription_key

    response = requests.get(base_url, params=params, headers=headers)
    response.raise_for_status()
    return response.json()

# %%
# lon lat
def get_opt_route(coords,time,api_key):
    features = []
    for idx, (lon, lat) in enumerate(coords):
        point_type = "waypoint" if idx in (0, len(coords) - 1) else "viaWaypoint"
        features.append({
            "type": "Feature",
            "geometry": {
                "coordinates": [lon, lat],
                "type": "Point"
            },
            "properties": {
                "pointIndex": idx,
                "pointType": point_type
            }
        })
    date = "2025-09-01T" + time + "-05:00" 

    body = {
        "type": "FeatureCollection",
        "features": features,
        "optimizeRoute": "fastestWithTraffic",
        "routeOutputOptions": ["itinerary","routePath"],
        "maxRouteCount": 1,
        "travelMode": "driving",
        "departAt": date
    }

    url = "https://atlas.microsoft.com/route/directions"
    params = {"api-version": "2025-01-01"}

    response = requests.post(
        url,
        params=params,
        headers={
            "Content-Type": "application/json; charset=UTF-8",
            "subscription-key": api_key
        },
        json=body
    )
    response.raise_for_status()
    return response.json()

# %%
# Unidades de metros y segundos 
def get_vel_azure(features,elevation):
    route = {"coords":[],
             "speed_ms":[],
             "slope_pct":[],
             "time":[],
             "distance":[]
            }
    
    total_time = 0
    total_distance = 0

    for feature in features:
        props = feature["properties"]
        steps = props.get("steps", [])

        for step in steps:
            start_idx, end_idx = step["routePathRange"]["range"]

            step_duration = props.get("durationInSeconds", 0)
            step_distance = props.get("distanceInMeters", 0)
            num_points = end_idx - start_idx

            if num_points <= 0:
                continue

            duration_per_point = step_duration / num_points
            distance_per_point = step_distance / num_points
            for i in range(num_points):
                idx = start_idx + i
                
                lng, lat, alt = elevation[idx]

                prev_alt = route["coords"][-1][2] if len(route["coords"]) > 0 else alt

                delta_alt = alt - prev_alt
                slope = (delta_alt / distance_per_point * 100) if distance_per_point != 0 else 0

                speed = distance_per_point / duration_per_point 

                route["coords"].append([lng, lat, alt])
                route["speed_ms"].append(round(speed, 2))
                route["slope_pct"].append(round(slope, 2))
                route["time"].append(round(total_time, 2))
                route["distance"].append(round(total_distance, 2))

                total_time += duration_per_point
                total_distance += distance_per_point

                if idx == len(elevation)-2:
                    lng, lat, alt = elevation[-1]
                    route["coords"].append([lng, lat, alt])
                    route["speed_ms"].append(round((distance_per_point / duration_per_point), 2))
                    route["slope_pct"].append(round(slope, 2))
                    route["time"].append(round(total_time, 2))
                    route["distance"].append(round(total_distance, 2))
    return route

# %%
def get_vel(steps, elevation_data):
    route = {
        "coords": [],        # [lng, lat, alt] format
        "speed_ms": [],      # Speed in m/s
        "slope_deg": [],     # Slope in degrees
        "time": [],          # Cumulative time in seconds
        "distance": []       # Cumulative distance in meters
    }
    
    total_time = 0
    total_distance = 0

    for step in steps:
        start_idx, end_idx = step["way_points"]
        step_duration = step["duration"]  
        step_distance = step["distance"]  
        num_points = end_idx - start_idx

        if num_points <= 0:
            continue

        duration_per_point = step_duration / num_points
        distance_per_point = step_distance / num_points

        for i in range(num_points):
            idx = start_idx + i
            
            if idx >= len(elevation_data):
                break
                
            lng, lat, alt = elevation_data[idx]

            if len(route["coords"]) > 0:
                prev_lng, prev_lat, prev_alt = route["coords"][-1]
            else:
                prev_lng, prev_lat, prev_alt = lng, lat, alt

            horiz_dist = geodesic((prev_lat, prev_lng), (lat, lng)).meters

            delta_alt = alt - prev_alt

            slope_deg = math.degrees(math.atan2(delta_alt, horiz_dist)) if horiz_dist != 0 else 0

            speed_ms = (distance_per_point / duration_per_point) if duration_per_point != 0 else 0

            route["coords"].append([lng, lat, alt])
            route["speed_ms"].append(round(speed_ms, 2))
            route["slope_deg"].append(round(slope_deg, 2))
            route["time"].append(round(total_time, 2))
            route["distance"].append(round(total_distance, 2))

            total_time += duration_per_point
            total_distance += distance_per_point

            if idx == len(elevation_data)-2:
                lng, lat, alt = elevation_data[-1]
                delta_alt = alt - prev_alt
                horiz_dist = geodesic((prev_lat, prev_lng), (lat, lng)).meters
                slope_pct = (delta_alt / distance_per_point * 100) if distance_per_point != 0 else 0
                slope_deg = math.degrees(math.atan2(delta_alt, horiz_dist)) if horiz_dist != 0 else 0

                route["coords"].append([lng, lat, alt])
                route["speed_ms"].append(round(speed_ms, 2))
                route["slope_deg"].append(round(slope_deg, 2))
                route["time"].append(round(total_time, 2))
                route["distance"].append(round(total_distance, 2))

    return route

# %%
with open("exm.json","r") as f:
        medj = json.load(f)

with open("routes/ors_route.json","r") as f:
        ors = json.load(f);

with open("routes/azure_opt2.geojson","r") as f:
        azure_route = json.load(f);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 with open("exm.json","r") as f:
# ----> 2         medj = json.load(f)
#       4 with open("routes/ors_route.json","r") as f:
#       5         ors = json.load(f);
#
# NameError: name 'json' is not defined

# %%
st=ors["routes"][-1]["geometry"]

# %%
i = 0
#for row in medj[:500]:
#    print(i)
#    i = i + 1
#    if(row.get("route") is not None):
#        continue
#    else:
#        try:
#            coord = [[row["o_long"],row["o_lat"]],[row["d_long"],row["d_lat"]]]
#            # Conseguir la ruta con ORS
#            data = get_route(coord,ORS_API_KEY)
#
#            route_line = data["routes"][0]["geometry"]
#
#            route_data=convert.decode_polyline(route_line, True)["coordinates"]
#            
#            steps = data["routes"][0]["segments"][0]["steps"]
#            
#            # Conseguir la ruta con tráfico
#            data_opt = get_opt_route(coord,row["hora_o"],AZURE_API_KEY)
#            data_opt = data_opt["features"]
#
#            line_coords = data_opt[-1]["geometry"]["coordinates"][0]
#            elevation = get_alt(line_coords,ORS_API_KEY)
#            
#            row["route"] = get_vel(steps,route_data)
#            row["route_opt"] = get_vel_azure(data_opt,elevation)
#        except Exception as e:
#            print(e)
# Out:
#   Cell In[241], line 3
#     print(i)
#     ^
# IndentationError: unexpected indent

# %%
x=208
distance = geodesic(coords[x][0:2],coords[x+1][0:2]).meters
alt_dif = coords[x][-1] - coords[x+1][-1]

angle_rad = math.atan2(alt_dif, distance)       
angle_deg = math.degrees(angle_rad)

angle_deg
# Out:
# -75.1738255014392

# %%
angles = [math.degrees(
            math.atan2(
               coords[x][-1] - coords[x+1][-1],
               geodesic(coords[x][0:2],coords[x+1][0:2]).meters
                     )
         ) for x in range(len(coords)-1)]

# %%
amva = pd.read_json("results/amva.json")

# %%
def get_matriz_od(m):
    rows = []
    for i, row in m.iterrows():   
        for j,destino in m.iterrows():
            if i != j:
                new_row = row.copy()
                new_row["municipio_d"] = destino["municipio_o"]
                new_row["comuna_d"] = destino["comuna_o"]
                new_row["d_long"] = destino["o_long"]
                new_row["d_lat"] = destino["o_lat"]
                rows.append(new_row)
    return pd.DataFrame(rows)

# %%
municipios = amva["municipio_o"].unique()
m = pd.DataFrame(columns=amva.columns)
x=22
for i in range(len(municipios)):
    m.loc[len(m)] = amva[amva["municipio_o"]==municipios[i]].iloc[x].values
    m.loc[len(m)] = amva[amva["municipio_o"]==municipios[i]].iloc[x+1].values

# %%
expand_m = get_matriz_od(m)

# %%
row = expand_m.iloc[0]
coords = [[row["o_long"],row["o_lat"]],[row["d_long"],row["d_lat"]]]
coords
# Out:
# [[-75.6366550535, 6.1678892824], [-75.6105783914, 6.1665758239]]

# %%
mj = expand_m.to_json(orient='split', date_format='iso', indent=2)
type(mj)
# Out:
# str

# %%
expand_m.iloc[20:30]
# Out:
#    municipio_o          comuna_o    hora_o  municipio_d            comuna_d  \
# 20      Itagui  Itagui-Comuna 02  19:00:00     Medellin               Belen
# 21      Itagui  Itagui-Comuna 02  19:00:00     Medellin               Belen
# 22      Itagui  Itagui-Comuna 02  19:00:00        Bello     Bello-Comuna 02
# 23      Itagui  Itagui-Comuna 02  19:00:00        Bello     Bello-Comuna 02
# 24      Itagui  Itagui-Comuna 02  19:00:00  La Estrella  Urbana La Estrella
# 25      Itagui  Itagui-Comuna 02  19:00:00  La Estrella  Urbana La Estrella
# 26      Itagui  Itagui-Comuna 02  19:00:00     Sabaneta     Urbana Sabaneta
# 27      Itagui  Itagui-Comuna 02  19:00:00     Sabaneta     Urbana Sabaneta
# 28      Itagui  Itagui-Comuna 02  19:00:00     Envigado             Zona 07
# 29      Itagui  Itagui-Comuna 02  19:00:00     Envigado             Zona 09
#
#       hora_d motivo_viaje          modo_tte     o_long     o_lat     d_long  \
# 20  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.594047
# 21  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.591182
# 22  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.528188
# 23  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.583397
# 24  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.638589
# 25  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.644071
# 26  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.608774
# 27  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.618996
# 28  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.582148
# 29  19:20:00         Casa  Moto (Conductor) -75.610578  6.166576 -75.563431
#
#        d_lat                                             slopes  \
# 20  6.222594  [[0, 1.25, 0.0, -1.05, 0.0, 3.16, 0.0, 0.0, -1...
# 21  6.230922  [[0, 1.25, 0.0, -1.05, 0.0, 3.16, 0.0, 0.0, -1...
# 22  6.338090  [[0, 1.25, 0.0, -1.05, 0.0, 3.16, 0.0, 0.0, -1...
# 23  6.316436  [[0, 1.25, 0.0, -1.05, 0.0, 3.16, 0.0, 0.0, -1...
# 24  6.156683  [[0, -3.93, 0.28, 0.0, -3.83, 1.03, 0.0, 1.9, ...
# 25  6.160865                                               None
# 26  6.160816                                               None
# 27  6.153043                                               None
# 28  6.181187                                               None
# 29  6.166540                                               None
#
#                                                coords  \
# 20  [[[-75.61083, 6.16647, 1569.8], [-75.61102, 6....
# 21  [[[-75.61083, 6.16647, 1569.8], [-75.61102, 6....
# 22  [[[-75.61083, 6.16647, 1569.8], [-75.61102, 6....
# 23  [[[-75.61083, 6.16647, 1569.8], [-75.61102, 6....
# 24  [[[-75.61083, 6.16647, 1569.8], [-75.61077, 6....
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
#
#                                                speeds
# 20  [[4.17, 4.17, 4.17, 4.17, 4.17, 4.17, 4.17, 10...
# 21  [[4.17, 4.17, 4.17, 4.17, 4.17, 4.17, 4.17, 10...
# 22  [[4.17, 4.17, 4.17, 4.17, 4.17, 4.17, 4.17, 10...
# 23  [[4.17, 4.17, 4.17, 4.17, 4.17, 4.17, 4.17, 10...
# 24  [[4.17, 4.17, 11.79, 11.79, 11.79, 16.3, 16.3,...
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None

# %%
expand_m.drop("slopes", axis=1,inplace=True)
expand_m.head()
# Out:
#   municipio_o          comuna_o    hora_o municipio_d          comuna_d  \
# 0      Itagui  Itagui-Comuna 04  11:30:00      Itagui  Itagui-Comuna 02
# 1      Itagui  Itagui-Comuna 04  11:30:00    Medellin             Belen
# 2      Itagui  Itagui-Comuna 04  11:30:00    Medellin             Belen
# 3      Itagui  Itagui-Comuna 04  11:30:00       Bello   Bello-Comuna 02
# 4      Itagui  Itagui-Comuna 04  11:30:00       Bello   Bello-Comuna 02
#
#      hora_d motivo_viaje          modo_tte     o_long     o_lat     d_long  \
# 0  11:45:00      Trabajo  Moto (Conductor) -75.636655  6.167889 -75.610578
# 1  11:45:00      Trabajo  Moto (Conductor) -75.636655  6.167889 -75.594047
# 2  11:45:00      Trabajo  Moto (Conductor) -75.636655  6.167889 -75.591182
# 3  11:45:00      Trabajo  Moto (Conductor) -75.636655  6.167889 -75.528188
# 4  11:45:00      Trabajo  Moto (Conductor) -75.636655  6.167889 -75.583397
#
#       d_lat
# 0  6.166576
# 1  6.222594
# 2  6.230922
# 3  6.338090
# 4  6.316436

# %%
expand_m['slopes'] = None
expand_m['coords'] = None
expand_m['speeds'] = None

# %%
for idx, row in expand_m.iloc[:].iterrows():
    print(idx)
    if expand_m.iloc[idx]['slopes'] is not None:
        print("cede")
        continue
    else:
        coord = [[row["o_long"], row["o_lat"]], [row["d_long"], row["d_lat"]]]
        # Get route with ORS
        data = get_route(coord, ORS_API_KEY)
        route_line = data["routes"][0]["geometry"]
        route_data = convert.decode_polyline(route_line, True)["coordinates"]
        
        steps = data["routes"][0]["segments"][0]["steps"]
        route = get_vel(steps, route_data)
        
        expand_m.at[idx, "slopes"] = [route["slope_deg"]]
        expand_m.at[idx, "coords"] = [route["coords"]]
        expand_m.at[idx, "speeds"] = [route["speed_ms"]]
        time.sleep(2.5)
# Out:
# 0
# cede
# 1
# cede
# 2
# cede
# 3
# cede
# 4
# cede
# 5
# cede
# 6
# cede
# 7
# cede
# 8
# cede
# 9
# cede
# 10
# cede
# 11
# cede
# 12
# cede
# 13
# cede
# 14
# cede
# 15
# cede
# 16
# cede
# 17
# cede
# 18
# cede
# 19
# cede
# 20
# cede
# 21
# cede
# 22
# cede
# 23
# cede
# 24
# cede
# 25
# cede
# 26
# cede
# 27
# cede
# 28
# cede
# 29
# cede
# 30
# cede
# 31
# cede
# 32
# cede
# 33
# cede
# 34
# cede
# 35
# cede
# 36
# cede
# 37
# cede
# 38
# cede
# 39
# cede
# 40
# cede
# 41
# cede
# 42
# cede
# 43
# cede
# 44
# cede
# 45
# cede
# 46
# cede
# 47
# cede
# 48
# cede
# 49
# cede
# 50
# cede
# 51
# cede
# 52
# cede
# 53
# cede
# 54
# cede
# 55
# cede
# 56
# cede
# 57
# cede
# 58
# cede
# 59
# cede
# 60
# cede
# 61
# cede
# 62
# cede
# 63
# cede
# 64
# cede
# 65
# cede
# 66
# cede
# 67
# cede
# 68
# cede
# 69
# cede
# 70
# cede
# 71
# cede
# 72
# cede
# 73
# cede
# 74
# cede
# 75
# cede
# 76
# cede
# 77
# cede
# 78
# cede
# 79
# cede
# 80
# cede
# 81
# cede
# 82
# cede
# 83
# cede
# 84
# cede
# 85
# cede
# 86
# cede
# 87
# cede
# 88
# cede
# 89
# cede
# 90
# cede
# 91
# cede
# 92
# cede
# 93
# cede
# 94
# cede
# 95
# cede
# 96
# cede
# 97
# cede
# 98
# cede
# 99
# cede
# 100
# cede
# 101
# cede
# 102
# cede
# 103
# cede
# 104
# cede
# 105
# cede
# 106
# cede
# 107
# cede
# 108
# cede
# 109
# cede
# 110
# cede
# 111
# cede
# 112
# cede
# 113
# cede
# 114
# cede
# 115
# cede
# 116
# cede
# 117
# cede
# 118
# cede
# 119
# cede
# 120
# cede
# 121
# cede
# 122
# cede
# 123
# cede
# 124
# cede
# 125
# cede
# 126
# cede
# 127
# cede
# 128
# cede
# 129
# cede
# 130
# cede
# 131
# cede
# 132
# cede
# 133
# cede
# 134
# cede
# 135
# cede
# 136
# cede
# 137
# cede
# 138
# cede
# 139
# cede
# 140
# cede
# 141
# cede
# 142
# cede
# 143
# cede
# 144
# cede
# 145
# cede
# 146
# cede
# 147
# cede
# 148
# cede
# 149
# cede
# 150
# cede
# 151
# cede
# 152
# cede
# 153
# cede
# 154
# cede
# 155
# cede
# 156
# cede
# 157
# cede
# 158
# cede
# 159
# cede
# 160
# cede
# 161
# cede
# 162
# cede
# 163
# cede
# 164
# cede
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379

# %%
expand_m.to_json("matrix/amva_routes.json",orient="records", indent=1)

# %%
lop = pd.read_json("matrix/amva_routes.json")

# %%
center_lat = m["o_lat"].mean()
center_long = m["o_long"].mean()

mapa = folium.Map(location=[center_lat, center_long], zoom_start=11)

for _, row in m.iterrows():
    folium.Marker(
        location=[row["o_lat"], row["o_long"]],
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cf51ee3a3d028c5935c0f5599f0e565 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cf51ee3a3d028c5935c0f5599f0e565&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cf51ee3a3d028c5935c0f5599f0e565 = L.map(
#                 &quot;map_1cf51ee3a3d028c5935c0f5599f0e565&quot;,
#                 {
#                     center: [6.244086378605, -75.55508912793],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd47306a13913669222f0994771cafc1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fd47306a13913669222f0994771cafc1.addTo(map_1cf51ee3a3d028c5935c0f5599f0e565);
#
#
#             var marker_4683b9ca06235c7f41f47b4d3c30201a = L.marker(
#                 [6.1678892824, -75.6366550535],
#                 {
# }
#             ).addTo(map_1cf51ee3a3d028c5935c0f5599f0e565);
#
#
#             var icon_72d86e101dd103e9ad929598b175e0e1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_4683b9ca06235c7f41f47b4d3c30201a.setIcon(icon_72d86e101dd103e9ad929598b175e0e1);
#
#
#             var marker_eb34f7ed43f3751e90b1b132765bd016 = L.marker(
#                 [6.1665758239, -75.6105783914],
#                 {
# }
#             ).addTo(map_1cf51ee3a3d028c5935c0f5599f0e565);
#
#
#             var icon_515af7a2e3276ba5f059ec25bfb74de4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_eb34f7ed43f3751e90b1b132765bd016.setIcon(icon_515af7a2e3276ba5f059ec25bfb74de4);
#
#
#             var marker_f01c541561af39c9d03eda60390c1cf2 = L.marker(
#                 [6.222594072, -75.5940474633],
#                 {
# }
#             ).addTo(map_1cf51ee3a3d028c5935c0f5599f0e565);
#
#
#             var icon_5b2aa955dd07a7e58929fe2a8b591048 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_f01c541561af39c9d03eda60390c1cf2.setIcon(icon_5b2aa955dd07a7e58929fe2a8b591048);
#
#
#             var marker_d3a05537c3e4b2727d9e0bae0e1ddc82 = L.marker(
#                 [6.2309222905, -75.5911818403],
#                 {
# }
#             ).addTo(map_1cf51ee3a3d028c5935c0f5599f0e565);
#
#
#             var icon_ca347c89763f5014fd5f4b773af9bb8c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_d3a05537c3e4b2727d9e0bae0e1ddc82.setIcon(icon_ca347c89763f5014fd5f4b773af9bb8c);
#
#
#             var marker_255a13b3d4c798423796c208d4658efa = L.marker(
#                 [6.33808965, -75.5281877082],
#                 {
# }
#             ).addTo(map_1cf51ee3a3d028c5935c0f5599f0e565);
#
#
#             var icon_de9fbd64528ca760a2fec382c0b93f98 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_255a13b3d4c798423796c208d4658efa.setIcon(icon_de9fbd64528ca760a2fec382c0b93f98);
#
#
#             var marker_e80b64083a585d7fecc17f6baa1e7eca = L.marker(
#                 [6.3164361852, -75.5833969716],
#                 {
# }
#             ).addTo(map_1cf51ee3a3d028c5935c0f5599f0e565);
#
#
#             var icon_14b2816be302d4e6029bd239aafecd13 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info

# %%
len(m)
# Out:
# 20
